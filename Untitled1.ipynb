# %%
# 데이터 출처: https://www.djtp.or.kr/

# %%
# 라이브러리 탑재
import folium

# 기본 대전 지도 그래프 표기
Daejeon = folium.Map(location= [36.3504, 127.3845], zoom_start = 12)
Daejeon
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
# 판다스 모듈 탑재
import pandas as pd

# 승하차 인원 excel 파일 읽어오기
data = pd.read_excel("/content/붙임_대전도시철도공사_공공데이터_목록.xlsx")

# 데이터 확인하기

# %%
# 지하철 역 정보 excel 파일 읽어오기
station_info = pd.read_excel("/content/붙임_대전도시철도공사_공공데이터_목록.xlsx")

# 데이터 확인하기
station_info
# Out:
#                         [붙임]                  Unnamed: 1 Unnamed: 2  \
# 0    대전도시철도공사 공공데이터 포털 개방 목록                         NaN        NaN
# 1         * 공공데이터 포털 링크 : 링크                         NaN        NaN
# 2                         연번                         목록명       목록타입
# 3                          1                     역명 및 주소      오픈API
# 4                          2             역사 이름 다국어 데이터세트      파일데이터
# ..                       ...                         ...        ...
# 101                       99                   도시철도 환승정보      오픈API
# 102                      100                    승강기 점검일정      오픈API
# 103                      101  열차혼잡도 분석 결과_2020년01월 ~ 06월      파일데이터
# 104                      102               역간 소요시간/거리/요금      오픈API
# 105                      103                       열차시각표      오픈API
#
#               Unnamed: 3           Unnamed: 4
# 0                    NaN                  NaN
# 1                    NaN                  NaN
# ...

# %%
# 승하차 인원 데이터 상세 정보 확인하기
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 106 entries, 0 to 105
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   [붙임]        106 non-null    object
#  1   Unnamed: 1  104 non-null    object
#  2   Unnamed: 2  104 non-null    object
#  3   Unnamed: 3  104 non-null    object
#  4   Unnamed: 4  104 non-null    object
# dtypes: object(5)
# memory usage: 4.3+ KB
